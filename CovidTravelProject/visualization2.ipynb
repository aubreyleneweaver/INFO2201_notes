# %%
import pandas as pd
import pickle
import seaborn as sns
import matplotlib.pyplot as plt

# %%
CovidTravelDF = pd.read_csv("US_Covid_and_Travel_Data.csv")

CovidTravelDF.head()
# Out:
#    Year  Month_number     Month  New_cases  Cumulative_cases  New_deaths  \
# 0  2020             1   January          8                 8           0
# 1  2020             2  February         61                69           1
# 2  2020             3     March     173074            173143        3326
# 3  2020             4     April     857163           1030306       57134
# 4  2020             5       May     755116           1785422       44864
#
#    Cumulative_deaths  Foreign_originating  Foreign_returning  \
# 0                  0              5274405            5520357
# 1                  1              4470729            4448720
# 2               3327              1960896            2946059
# 3              60461                54031             176627
# 4             105325                78337             192614
#
#    US_citizen_originating  US_citizen_returning Timestamp
# 0                 4073096               5218812   2020-01
# ...

# %%
CovidTravelDF = titanicDf[["PassengerId", "Age"]]
